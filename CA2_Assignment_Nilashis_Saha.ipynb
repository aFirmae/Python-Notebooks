# %% [markdown]
# <a href="https://colab.research.google.com/github/aFirmae/Python-Notebooks/blob/main/CA2_Assignment_Nilashis_Saha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Bucket Sort

# %%
def bucket_sort(array):
    min_value = min(array)
    max_value = max(array)

    bucket_count = max(1, max_value - min_value + 1)
    buckets = [[] for _ in range(bucket_count)]

    for element in array:
        index = element - min_value
        buckets[index].append(element)

    sorted_array = []
    for bucket in buckets:
      sorted_array.extend(bucket)

    return sorted_array

data = [5, 2, 9, 1, 5, 6, 3]
sorted_data = bucket_sort(data)
print(sorted_data)

# %% [markdown]
# ### Merge Sort

# %%
def merge_sort(array):
    if len(array) <= 1:
        return array

    mid = len(array) // 2
    left_half = array[:mid]
    right_half = array[mid:]

    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)

    return merge(left_half, right_half)


def merge(left, right):
    merged = []
    left_index = 0
    right_index = 0

    while left_index < len(left) and right_index < len(right):
        if left[left_index] < right[right_index]:
            merged.append(left[left_index])
            left_index += 1
        else:
            merged.append(right[right_index])
            right_index += 1

    merged.extend(left[left_index:])
    merged.extend(right[right_index:])

    return merged

data = [5, 2, 9, 1, 5, 6, 3]
sorted_data = merge_sort(data)
sorted_data

# %% [markdown]
# ### Bubble Sort

# %%
def bubble_sort(array):
    n = len(array)
    for i in range(n):
        swapped = False
        for j in range(0, n - i - 1):
            if array[j] > array[j + 1]:
                array[j], array[j + 1] = array[j + 1], array[j]
                swapped = True
        if not swapped:
            break
    return array

data = [5, 2, 9, 1, 5, 6, 3]
sorted_data = bubble_sort(data)
sorted_data

# %% [markdown]
# ### Different plots in one plot using Matplotlib

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y1 = [2, 4, 1, 5, 3]
y2 = [1, 3, 2, 4, 5]
y3 = [3, 1, 4, 2, 5]

# Create the plot
plt.figure(figsize=(8, 6))

# First line
plt.plot(x, y1, label='Line 1', marker='o', linestyle='-')

# Second line
plt.plot(x, y2, label='Line 2', marker='s', linestyle='--')

# Third line
plt.plot(x, y3, label='Line 3', marker='^', linestyle='-.')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple Lines in One Plot')
plt.grid(True)
plt.legend()

plt.show()
